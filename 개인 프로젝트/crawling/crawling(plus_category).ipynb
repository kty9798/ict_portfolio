# %% [markdown]
# > beautifulsoup 준비

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url = "https://search.shopping.naver.com/search/all?query=cos&frm=NVSHATC&prevQuery=%EC%A1%B0%EB%8D%98" # 네이버 쇼핑 주소. 검색대상마다 query 변경해주어야함
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html , 'html.parser')

# %% [markdown]
# > 연관검색어

# %%
#title = soup.find_all({"class":"relatedTags_relation_srh__1CleC" , "data-nclick":"N=a:rel.keyword"})
total = soup.find(class_ ="relatedTags_relation_srh__1CleC")
#title = soup.find_all(data-nclick = "N=a:rel.keyword")

'''
total = soup.find('a', href ="/search/all?query=%EB%82%98%EC%9D%B4%ED%82%A4%EC%A1%B0%EB%8D%98")
-> 태그명이랑 속성 둘다로 검색하는 방법
'''
# Out:
# '\ntotal = soup.find(\'a\', href ="/search/all?query=%EB%82%98%EC%9D%B4%ED%82%A4%EC%A1%B0%EB%8D%98")\n-> 태그명이랑 속성 둘다로 검색하는 방법\n'

# %%
temp = total.text #str
temp = temp[4:-8]
#print(total.text)

#속성으로 i.attr['a']
#print(temp[4:-8])  #연관 검색어 
print(temp)
# Out:
# cos반팔코스반팔원피스코스cos코스프레코스숄더백젝시믹스코스반바지캉캉미니원피스퍼프캉캉원피스폴로미쏘뷔스티에캉캉원피스보웬원피스타임원피스하프클럽여성의류쇼핑몰메이블루썸제이바캉스원피스휴양지원피스플라이모델라탄크로스백복조리에코백여자꾸안꾸룩사각사각원피스허리셔링원피스큰가방여자오피스룩오피스원피스토리버치원피스

# %%
title_list = []
for t in total:
    title_list.append(t.text)

print(title_list)
# Out:
# ['쇼핑연관', 'cos반팔코스반팔원피스코스cos코스프레코스숄더백젝시믹스코스반바지캉캉미니원피스퍼프캉캉원피스폴로미쏘뷔스티에캉캉원피스보웬원피스타임원피스하프클럽여성의류쇼핑몰메이블루썸제이바캉스원피스휴양지원피스플라이모델라탄크로스백복조리에코백여자꾸안꾸룩사각사각원피스허리셔링원피스큰가방여자오피스룩오피스원피스토리버치원피스', '연관검색어더보기']

# %%
for i in soup.findAll(class_ ="relatedTags_relation_srh__1CleC"):
  for j in i.findAll("a"):
    print (j.get_text())
# Out:
# cos반팔
# 코스반팔원피스
# 코스cos
# 코스프레
# 코스숄더백
# 젝시믹스
# 코스반바지
# 캉캉미니원피스
# 퍼프캉캉원피스
# 폴로
# 미쏘
# 뷔스티에캉캉원피스
# 보웬원피스
# 타임원피스
# 하프클럽
# 여성의류쇼핑몰
# 메이블루
# 썸제이
# 바캉스원피스
# 휴양지원피스
# 플라이모델
# 라탄크로스백
# 복조리에코백
# 여자꾸안꾸룩
# 사각사각원피스
# 허리셔링원피스
# 큰가방
# 여자오피스룩
# 오피스원피스
# 토리버치원피스

# %% [markdown]
# > 카테고리 (이상하게 다섯개만 나옴)

# %%
for i in soup.findAll(class_ ="basicList_info_area__17Xyo"):
  for j in i.findAll(class_="basicList_category__wVevj"):
    print (j.get_text())
# 왜 옷 부분들은 안되지
# Out:
# 패션의류
# 여성의류
# 원피스
# 패션의류
# 여성의류
# 원피스
# 패션의류
# 여성의류
# 티셔츠
# 패션의류
# 여성의류
# 원피스
# 패션의류
# 여성의류
# 원피스

# %% [markdown]
# > 상품명단어 (왜 카테고리도 그렇고 다섯 개만 나오지!!)

# %% [markdown]
# * 가장 많이 사용된 순서로 정렬되어야
# * 참고 : https://dalulu.tistory.com/108

# %%
for i in soup.findAll(class_="basicList_link__1MaTN") :
  print(i.get_text())
# Out:
# 코스 드레스 롱 LONG CRINKLED DRESS 0985112001 3524624
# 코스 드레스 미디 SCUBA MIDI DRESS 0971981001 3189989
# 코스 탑 CRINKLED TOP 0984640003 5304871
# COS 코스 플리티드 미디 티셔츠 원피스
# COS 코스 여자 MODAL 릴렉스드핏 퍼프 슬리브 GATHERED 허리 반팔 드레스 0958612001

# %%
box = []
result=[]

for i in soup.findAll(class_="basicList_link__1MaTN") :
  box.append(i.get_text())
print(box,'\n')

for i in range(len(box)):
  result_i = box[i].split()
  result += result_i
  # print(result_i)
print(result)
# result -> 제목에 쓰인 단어들을 전체 하나로 묶은 리스트
# Out:
# ['코스 드레스 롱 LONG CRINKLED DRESS 0985112001 3524624', '코스 드레스 미디 SCUBA MIDI DRESS 0971981001 3189989', '코스 탑 CRINKLED TOP 0984640003 5304871', 'COS 코스 플리티드 미디 티셔츠 원피스', 'COS 코스 여자 MODAL 릴렉스드핏 퍼프 슬리브 GATHERED 허리 반팔 드레스 0958612001']
#
# ['코스', '드레스', '롱', 'LONG', 'CRINKLED', 'DRESS', '0985112001', '3524624', '코스', '드레스', '미디', 'SCUBA', 'MIDI', 'DRESS', '0971981001', '3189989', '코스', '탑', 'CRINKLED', 'TOP', '0984640003', '5304871', 'COS', '코스', '플리티드', '미디', '티셔츠', '원피스', 'COS', '코스', '여자', 'MODAL', '릴렉스드핏', '퍼프', '슬리브', 'GATHERED', '허리', '반팔', '드레스', '0958612001']

# %%
from collections import Counter
count = Counter(result)
tag_count = []
tags = []
for n, c in count.most_common(100):
  dics = {'tag': n, 'count': c}
  if len(dics['tag']) >= 2 and len(tags) <= 49:
    tag_count.append(dics) # 항목별 개수가 저장된 것을 전체 리스트 tag_count에 딕셔너리 하나씩 넣음
    tags.append(dics['tag'])

# %%
for tag in tag_count:
  print(" {:<14}".format(tag['tag']), end='\t')
  print("{}".format(tag['count']))
# Out:
#  코스            	5
#  드레스           	3
#  CRINKLED      	2
#  DRESS         	2
#  미디            	2
#  COS           	2
#  LONG          	1
#  0985112001    	1
#  3524624       	1
#  SCUBA         	1
#  MIDI          	1
#  0971981001    	1
#  3189989       	1
#  TOP           	1
#  0984640003    	1
#  5304871       	1
#  플리티드          	1
#  티셔츠           	1
#  원피스           	1
#  여자            	1
#  MODAL         	1
#  릴렉스드핏         	1
#  퍼프            	1
#  슬리브           	1
#  GATHERED      	1
#  허리            	1
#  반팔            	1
#  0958612001    	1

# %%
tag_count # 빈도 정리된 거 # 뭐야 근데 이거 자동정렬된듯??!!!
# Out:
# [{'count': 5, 'tag': '코스'},
#  {'count': 3, 'tag': '드레스'},
#  {'count': 2, 'tag': 'CRINKLED'},
#  {'count': 2, 'tag': 'DRESS'},
#  {'count': 2, 'tag': '미디'},
#  {'count': 2, 'tag': 'COS'},
#  {'count': 1, 'tag': 'LONG'},
#  {'count': 1, 'tag': '0985112001'},
#  {'count': 1, 'tag': '3524624'},
#  {'count': 1, 'tag': 'SCUBA'},
#  {'count': 1, 'tag': 'MIDI'},
#  {'count': 1, 'tag': '0971981001'},
#  {'count': 1, 'tag': '3189989'},
#  {'count': 1, 'tag': 'TOP'},
#  {'count': 1, 'tag': '0984640003'},
#  {'count': 1, 'tag': '5304871'},
#  {'count': 1, 'tag': '플리티드'},
#  {'count': 1, 'tag': '티셔츠'},
#  {'count': 1, 'tag': '원피스'},
#  {'count': 1, 'tag': '여자'},
#  {'count': 1, 'tag': 'MODAL'},
#  {'count': 1, 'tag': '릴렉스드핏'},
#  {'count': 1, 'tag': '퍼프'},
#  {'count': 1, 'tag': '슬리브'},
#  {'count': 1, 'tag': 'GATHERED'},
#  {'count': 1, 'tag': '허리'},
#  {'count': 1, 'tag': '반팔'},
#  {'count': 1, 'tag': '0958612001'}]

# %%
for i in range(len(tag_count)):
  print(tag_count[i]['tag'],end=' ')
# Out:
# 코스 드레스 CRINKLED DRESS 미디 COS LONG 0985112001 3524624 SCUBA MIDI 0971981001 3189989 TOP 0984640003 5304871 플리티드 티셔츠 원피스 여자 MODAL 릴렉스드핏 퍼프 슬리브 GATHERED 허리 반팔 0958612001

# %% [markdown]
# ###api 이용(태윤)

# %%
import urllib.request
import json
from bs4 import BeautifulSoup

idx = 0
display = 20
start =1
end = 20
client_id = "xrPeMbf10xfqjK2P4F5h"
client_secret = "ryuTHmg_Hp"  

q = input("검색어를 입력하시요: ")
encText = urllib.parse.quote("{}".format(q))
url = "https://openapi.naver.com/v1/search/shop?query=" + encText + "&display=" +str(display) + "&start=" + str(start) # json 결과
naver_api_request = urllib.request.Request(url)
naver_api_request.add_header("X-Naver-Client-Id",client_id)
naver_api_request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(naver_api_request)
rescode = response.getcode()
j=0
title_list =[]
if(rescode==200):
    response_body = response.read()
    
    result = json.loads(response_body.decode('utf-8'))
    items = result.get('items')
    contents = result.get('total') #개수

    #title = items.get("title")
    
    
    
    context = {
        'items': items,
        
                
        }
    
    for i in items:    
       #print(i['title'])
       #i가 아이템 한줄
       cleantext = BeautifulSoup(i['title'], "lxml").text  #태그가 들어있는 string 에서 <> 사이 내용 제거해주는 코드!
       title_list.append(cleantext)
       #print(cleantext)
    
    #print(title_list)

        
    #return render(request , "crawling.html" , context = context)       
else:
    print("Error Code:" + rescode) 

#_____________________________
# Out:
# 검색어를 입력하시요: 밥

# %% [markdown]
# ## 카테고리 가져오기
# * 거의 제목과 유사하지만 category1, category2 ,category3...등을 가져옴

# %%
import urllib.request
import json
from bs4 import BeautifulSoup

#가져오는 개수 display
idx = 0
display = 20
start =1
end = 20
client_id = "xrPeMbf10xfqjK2P4F5h"
client_secret = "ryuTHmg_Hp"  

# q = input("검색어를 입력하시요: ")
q = "책"
encText = urllib.parse.quote("{}".format(q))
url = "https://openapi.naver.com/v1/search/shop?query=" + encText + "&display=" +str(display) + "&start=" + str(start) # json 결과
naver_api_request = urllib.request.Request(url)
naver_api_request.add_header("X-Naver-Client-Id",client_id)
naver_api_request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(naver_api_request)
rescode = response.getcode()
j=0



category_list =[]
category_string = "category"

if(rescode==200):
    response_body = response.read()
    
    result = json.loads(response_body.decode('utf-8'))
    items = result.get('items')
    contents = result.get('total') #개수

    #title = items.get("title")
    
    for i in items:    
       #print(i['title'])
       #i가 아이템 한줄
      for k in range(1,4,1):
        category_string+= str(k)
        cleantext = BeautifulSoup(i[category_string], "lxml").text #태그가 들어있는 string 에서 <> 사이 내용 제거해주는 코드!
        category_list.append(cleantext)
        category_string = "category"
    
    print(category_list)

        
    
else:
    print("Error Code:" + rescode)
# Out:
# ['생활/건강', '문구/사무용품', '데스크용품', '생활/건강', '문구/사무용품', '데스크용품', '도서', '만화', 'SF/판타지', '생활/건강', '문구/사무용품', '데스크용품', '생활/건강', '문구/사무용품', '데스크용품', '생활/건강', '수납/정리용품', '정리함', '출산/육아', '완구/매트', '감각발달완구', '출산/육아', '완구/매트', '언어/학습완구', '생활/건강', '수납/정리용품', '정리함', '도서', '유아', '유아놀이책', '생활/건강', '문구/사무용품', '노트/수첩', '도서', '유아', '유아놀이책', '생활/건강', '문구/사무용품', '노트/수첩', '생활/건강', '문구/사무용품', '스탬프/도장', '도서', '유아', '유아학습', '생활/건강', '문구/사무용품', '데스크용품', '생활/건강', '문구/사무용품', '데스크용품', '도서', '사회/정치', '정치/외교', '생활/건강', '문구/사무용품', '데스크용품', '생활/건강', '문구/사무용품', '사무용품']
